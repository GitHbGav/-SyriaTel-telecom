# %%
import pandas as pd

pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 55)

# %%
vehicles =pd.read_csv('../data/Traffic_Crashes_Vehicles.csv')
vehicles.head()
# Out:
#    CRASH_UNIT_ID                                         CRASH_RECORD_ID  \
# 0        1670650  ced6312ffce9d7c3e1aaa3dc60fab43beffe278fa895b033ccf...
# 1        1670651  ced6312ffce9d7c3e1aaa3dc60fab43beffe278fa895b033ccf...
# 2        1670629  e6f08f85415d7ce2941b95f0cee657c1c76032238d2f0a6dd38...
# 3        1670630  e6f08f85415d7ce2941b95f0cee657c1c76032238d2f0a6dd38...
# 4        1670628  eb7e8d620bfdc6c070127dc08de11229fab51363fed346a4387...
#
#   RD_NO              CRASH_DATE  UNIT_NO UNIT_TYPE  NUM_PASSENGERS  \
# 0   NaN  09/28/2023 11:00:00 PM        1    DRIVER             NaN
# 1   NaN  09/28/2023 11:00:00 PM        2    PARKED             NaN
# 2   NaN  09/28/2023 10:56:00 PM        1    DRIVER             1.0
# 3   NaN  09/28/2023 10:56:00 PM        2    PARKED             NaN
# 4   NaN  09/28/2023 09:45:00 PM        1    DRIVER             NaN
#
#    VEHICLE_ID CMRC_VEH_I   MAKE    MODEL LIC_PLATE_STATE  VEHICLE_YEAR  \
# ...

# %%
#vehicles.isnull().sum()

# %% [markdown]
# Going to drop some colums as I just want to look into the crash types

# %%
vehicles.drop(columns = ["HAZMAT_CLASS","MCS_OUT_OF_SERVICE_I","HAZMAT_OUT_OF_SERVICE_I","CARGO_BODY_TYPE","LOAD_TYPE",
                         "VEHICLE_CONFIG","AXLE_CNT","TOTAL_VEHICLE_LENGTH","TRAILER2_LENGTH","TRAILER1_LENGTH","TRAILER2_WIDTH",
                         "TRAILER1_WIDTH","WIDE_LOAD_I","IDOT_PERMIT_NO","HAZMAT_VIO_CAUSE_CRASH_I","MCS_REPORT_NO","MCS_REPORT_I",
                         "","","","","","","",""])
